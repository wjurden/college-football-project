# %% [markdown]
# # Excitment Index Exploratory Data Analysis

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

os.chdir('/Users/wesjurden/Documents/GitHub/Personal/college-football-project/data/clean')

df = pd.read_csv('game_data_2022_clean.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3668 entries, 0 to 3667
# Data columns (total 33 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   attendance          0 non-null      float64
#  1   away_conference     3615 non-null   object
#  2   away_division       3615 non-null   object
#  3   away_id             3668 non-null   int64
#  4   away_line_scores    3655 non-null   object
#  5   away_points         3367 non-null   float64
#  6   away_post_win_prob  1409 non-null   float64
#  7   away_postgame_elo   735 non-null    float64
#  8   away_pregame_elo    738 non-null    float64
#  9   away_team           3668 non-null   object
#  10  completed           3668 non-null   bool
#  11  conference_game     3668 non-null   bool
#  12  excitement_index    1413 non-null   float64
#  13  highlights          0 non-null      float64
#  14  home_conference     3659 non-null   object
# ...

# %% [markdown]
# ## Describing Data

# %%
# Creating a variable to make the data easier to work with
ex = df['excitement_index']

# %%
# Summary Stats
ex.describe()
# Out:
# count    1413.000000
# mean        4.858429
# std         2.653033
# min         0.246965
# 25%         2.633540
# 50%         4.563707
# 75%         6.780999
# max        16.521828
# Name: excitement_index, dtype: float64

# %%
# There are a lot of null values. 
ex.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3668 entries, 0 to 3667
# Series name: excitement_index
# Non-Null Count  Dtype
# --------------  -----
# 1413 non-null   float64
# dtypes: float64(1)
# memory usage: 28.8 KB

# %%
# Null data
df[df.excitement_index.isnull()]
# Out:
#       attendance              away_conference away_division  away_id  \
# 2            NaN                         SIAC            II     2206
# 4            NaN                      Big Sky           FCS      304
# 15           NaN                    Lone Star            II     2201
# 16           NaN  Pennsylvania State Athletic            II     2974
# 17           NaN                    Wisconsin           III      272
# ...          ...                          ...           ...      ...
# 3656         NaN                          CAA           FCS      257
# 3662         NaN              American Rivers           III     2685
# 3663         NaN                   Gulf South            II   110242
# 3666         NaN  Pennsylvania State Athletic            II     2974
# 3667         NaN           American Southwest           III     2371
#
#      away_line_scores  away_points  away_post_win_prob  away_postgame_elo  \
# ...

# %% [markdown]
# ## Plotting Excitment Index

# %%
plt.title('Distribution of Excitement Index')
plt.hist(ex)
# Out:
# (array([199., 320., 269., 265., 228.,  89.,  25.,  12.,   3.,   3.]),
#  array([ 0.246965  ,  1.87445128,  3.50193755,  5.12942383,  6.75691011,
#          8.38439638, 10.01188266, 11.63936894, 13.26685521, 14.89434149,
#         16.52182776]),
#  <BarContainer object of 10 artists>)

# %%
ex.plot(kind='box', vert = False)
plt.title('Excitement Index Box Plot')
# Out:
# Text(0.5, 1.0, 'Excitement Index Box Plot')

# %% [markdown]
# Anything over 13 is an outlier

# %%
# Pulling all games with an excitment index of greater than 13
df[df.excitement_index > 13]
# Out:
#       attendance away_conference away_division  away_id    away_line_scores  \
# 21           NaN    Atlantic Sun           FCS     2453     [0, 7, 0, 7, 0]
# 537          NaN       Big South           FCS     2523        [7, 0, 0, 7]
# 1975         NaN             CAA           FCS      160        [7, 7, 0, 0]
# 2522         NaN             Ivy           FCS      219       [0, 7, 17, 7]
# 2733         NaN    Atlantic Sun           FCS     2453       [0, 7, 7, 15]
# 2824         NaN             ACC           FBS       59      [10, 3, 3, 12]
# 3619         NaN          Big 12           FBS      201  [14, 10, 7, 17, 0]
#
#       away_points  away_post_win_prob  away_postgame_elo  away_pregame_elo  \
# 21           14.0            0.248242                NaN               NaN
# 537          14.0            0.001647                NaN               NaN
# 1975         14.0            0.993997                NaN               NaN
# ...
